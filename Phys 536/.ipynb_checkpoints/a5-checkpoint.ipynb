# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
plt.style.use(['science', 'notebook'])

# %% [markdown]
# # Question 1

# %% [markdown]
# The total number of cells is given by the sum of the cells in each of the subpopulations $N=\sum_i N_i$. Each of the subpoplulations has its own decay parameters $(\alpha_i, \beta_i)$. Based on the Poisson model, each subpopluation decays as
#
# $$N_i(D) = N_i(0)e^{-\alpha_i D - \beta_i dD}$$
#
# The total decay is thus given by
#
# $$N(D) = \sum_i N_i(0)e^{-\alpha_i D - \beta_i dD}$$

# %% [markdown]
# Define initial cells, proportion of subpopulations, dose per fraction, and $\alpha$ and $\beta$ values for each subpopulation.

# %%
N0 = 4e6
p1 = np.array([[1/3,1/3,1/3]])
p2 = np.array([[1/3,0.167,0.5]])
p3 = np.array([[0.5,0.25,0.25]])
d = 2
D = np.linspace(0,70,100)
alpha = np.array([0.18, 0.2, 0.22])
beta = alpha/10

# %% [markdown]
# Obtain the number of cells as a function of dose for each of the three different populations

# %%
Nis1 = N0*p1.T*np.exp(-np.outer(alpha, D)-d*np.outer(beta,D))
Nis2 = N0*p2.T*np.exp(-np.outer(alpha, D)-d*np.outer(beta,D))
Nis3 = N0*p3.T*np.exp(-np.outer(alpha, D)-d*np.outer(beta,D))
N1 = np.sum(Nis1, axis=0)
N2 = np.sum(Nis2, axis=0)
N3 = np.sum(Nis3, axis=0)

# %% [markdown]
# Plot:

# %%
plt.plot(D, N1, label=r'$p=(1/3,1/3,1/3)$')
plt.plot(D, N2, label=r'$p=(1/3,1/6,1/2)$')
plt.plot(D, N3, label=r'$p=(1/2,1/4,1/4)$')
plt.semilogy()
plt.legend(facecolor='white', framealpha=1, frameon=True)
plt.xlabel('Absorbed Dose [Gy]')
plt.ylabel('Total Cell Population')
plt.grid()

# %%
print(f'Final Cell Population Case 1: {N1[-1]:.2f}')
print(f'Final Cell Population Case 2: {N2[-1]:.2f}')
print(f'Final Cell Population Case 3: {N3[-1]:.2f}')
# Out:
# Final Cell Population Case 1: 0.44
# Final Cell Population Case 2: 0.41
# Final Cell Population Case 3: 0.60

# %% [markdown]
# From this plot it is clear that the subpopulation mostly responsible for the outcome is the subpopulation with the lowest $\alpha$ value. This is because
#
# * The shape of the curve does not change when proportions $p_2$ and $p_3$ are adjusted, which have higher values of $\alpha$.
# * The shape of the curve changes when the proportion of cells $p_1$ with the lowest corresponding value of $\alpha$ change. This is represented by the orange curve.

# %% [markdown]
# # Question 2

# %% [markdown]
# Put the data into numpy arrays

# %%
p = np.array([0.2,0.2,0.15,0.1,0.35,0])
D = np.array([7000,6900,6500,5500,3800,0])
p_cumulative = np.flip(p.cumsum())
D_cumulative = np.flip(D)

# %% [markdown]
# Produce the plot

# %%
plt.figure(figsize=(8,3))
plt.step(D_cumulative,p_cumulative*100)
plt.grid()
plt.ylabel('% Volume')
plt.xlabel('Dose [cGy]')
plt.ylim(0,110)
plt.show()

# %% [markdown]
# Compute the efective volume (in percent), using
#
# $$V_{eff} = \sum_i v_i \left(\frac{D_i}{D_{max}}\right)^{1/n}$$
#
# where $n=0.12$ for the rectum.

# %%
peff = np.sum(p*(D/D.max())**(1/0.12))
print(f'The reduced DVH corresponds to is Veff={peff*100:.2f}% and Deff={D.max():.2f}Gy')
# Out:
# The reduced DVH corresponds to is Veff=47.38% and Deff=7000.00Gy

# %% [markdown]
# Show the reduced DVH next to the DVH on a plot:

# %%
plt.figure(figsize=(8,3))
plt.step(D_cumulative,p_cumulative*100, label='DVH')
plt.axhline(peff*100, color='r', ls='--', label='Reduced DVH')
plt.grid()
plt.ylabel('% Volume')
plt.xlabel('Dose [cGy]')
plt.ylim(0,110)
plt.legend(facecolor='white', framealpha=1, frameon=True)
plt.show()

# %% [markdown]
# # Question 3

# %% [markdown]
# The total surviving fraction of cells after $i$ procedures given in immediate succession (no repopulation in between) is given by
#
# $$SF_{tot} = \prod_{i} SF_i $$
#
# The BED for each surviving fraction $i$ is given by $e^{-\alpha BED_i} = SF_i$. This implies that
#
# $$SF_{tot} = \prod_i e^{-\alpha BED_i} = e^{-\alpha \sum_i BED_i}$$
#
# The total BED is given by
#
# $$SF_{tot} = e^{-\alpha BED}$$
#
# Equating these last two equations:
#
# $$e^{-\alpha BED} = e^{-\alpha \sum_i BED}$$
#
# and equating the terms in the exponentials:
#
# $$BED = \sum_i BED_i$$

# %% [markdown]
# # Question 4

# %% [markdown]
# For fractionated exposure without accounting for proliferation
#
# $$BED = D(1+d/(\alpha/\beta))$$
#
# implying that
#
# $$\frac{1}{D} = \frac{1}{BED} + \frac{1}{BED (\alpha/\beta)}d$$
#
# Referring to $y=mx+b$, we can identify
#
# * $1/D$ as $y$
# * $d$ as $x$
# * $\frac{1}{BED}$ as $b$ (intercept)
# * $\frac{1}{BED (\alpha/\beta)}$ as $m$ (slope)
#
# So it follows that $\alpha/\beta = b/m$ when fitting a best fit line to $1/D$ and $d$ data

# %%
d = np.array([2, 2.5, 2.9])
D = np.array([70, 2.5*25, 2.9*20])

# %% [markdown]
# Get function for line, and use `curve_fit` to obtain optimal values for $m$ and $b$.

# %%
def line(x, m, b):
    return m*x+b
(m,b), pcov = curve_fit(line, d, 1/D)
ratio = b/m

# %% [markdown]
# Print obtained value through best fit:

# %%
print(f'The value of alpha/beta is {ratio:.2f}Gy')
# Out:
# The value of alpha/beta is 2.35Gy
