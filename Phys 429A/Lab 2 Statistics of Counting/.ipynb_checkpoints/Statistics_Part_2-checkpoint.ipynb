# %% [markdown]
# <h1 id="tocheading">Table of Contents and Notebook Setup</h1>
# <div id="toc"></div>

# %%
# %%javascript
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy as sp
from scipy.optimize import curve_fit
from uncertainties import ufloat
import glob, os
from scipy import misc

# %%
datapath = 'radioactive_sources'

# %% [markdown]
# # Prelimary Work

# %% [markdown]
# ## Import all Data Sets into One Data Frame

# %%
datafiles = [file for file in os.listdir(datapath)]
list_ = []
for file_ in datafiles:
    df = pd.read_csv(datapath+'/'+file_, skiprows = 12, names=[file_[0:-10]])
    df=df[:-1] #get rid of last row
    df[file_[0:-10]] = df[file_[0:-10]].astype(int) #convert to numeric values
    list_.append(df)
df = pd.concat(list_, axis=1)

# %% [markdown]
# ## Remove Background Data From Each Column

# %% [markdown]
# Since the background was collected for 10 times longer than the isotopes, we divide the column by 10 and then subtract it from the other three columns.

# %%
df = df.subtract(df['background'], axis='rows', level=None, fill_value=None)
df.drop(['background'], axis=1, inplace=True)

# %% [markdown]
# ## Print some Sample Values

# %%
df
# Out:
#      co60  cs137  na22
# 0       0      0     0
# 1       0      0     0
# 2       0      0     0
# 3       0      0     0
# 4       0      0     0
# 5       0      0     0
# 6       0      0     0
# 7       0      0     0
# 8       0      0     0
# 9     157   1894    68
# 10    834  11828   475
# 11    906   7815   484
# 12    974   3790   554
# 13   1003   2109   644
# 14   1071   1704   605
# 15    999   1584   577
# 16   1004   1533   524
# 17   1020   1478   525
# 18   1110   1489   546
# 19   1150   1710   589
# 20   1315   1792   646
# 21   1555   2203   739
# 22   1796   2989   998
# 23   2249   3668  1343
# 24   2312   3834  1621
# 25   1993   3051  1288
# 26   1479   2479   953
# 27   1374   2253   907
# 28   1191   1932   733
# 29    985   1587   625
# ..    ...    ...   ...
# 482    10     -1     0
# 483    13      0     0
# 484    14     -1     0
# 485    12      0     0
# 486    20      1     1
# 487    15     -2    -1
# 488     9     -1     2
# 489    13      0     3
# 490    -1     -4    -3
# 491    16     -1     1
# 492    13      0     2
# 493    13      0     1
# 494    16      0     5
# 495    12      0     4
# 496     0      0     0
# 497     0      0     0
# 498     0      0     0
# 499     0      0     0
# 500     0      0     0
# 501     0      0     0
# 502     0      0     0
# 503     0      0     0
# 504     0      0     0
# 505     0      0     0
# 506     0      0     0
# 507     0      0     0
# 508     0      0     0
# 509     0      0     0
# 510     0      0     0
# 511     0      0     0
#
# [512 rows x 3 columns]

# %% [markdown]
# ## Initial Plot of Energy Peaks

# %%
fig, ax = plt.subplots(figsize=(12,6))

df.plot(ax=ax)

ax.set_xlabel('Channel Number (proportional to energy)')
ax.set_ylabel('Number of Counts')
ax.set_title('Energy Peaks of Different Isotopes')

ax.minorticks_on()
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)


plt.show()

# %% [markdown]
# # Fitting the Curves

# %% [markdown]
# ## Cobalt Peak 1

# %% [markdown]
# Use non-linear least squares to fit a function, f, to data.

# %%
def norm(x, u, sig, amp):
    return amp*np.exp(-((x-u)**2)/(2*sig**2))

# %%
mask = (df.index>320) & (df.index<345)
p0  = (np.mean(df.index[mask]), np.std(df.index[mask]), np.max(df['co60'][mask]))

popt, pcov = curve_fit(norm, df.index[mask], df['co60'][mask], p0=p0)
perr = np.sqrt(np.diag(pcov))

# %% [markdown]
# This returns the fit parameters in the array popt, and the <b> standard errors </b> (i.e one standard deviation) in the array pcov.

# %%
mean_co60_1 = popt[0]
err_co60_1 = perr[0]

# %%
fig, ax = plt.subplots(figsize=(6,4))

df['co60'].plot(ax=ax)
ax.plot(norm(df.index, mean_co60_1, popt[1], popt[2]))

ax.axvline(mean_co60_1, color='k', linestyle='--', label='Mean Value')
ax.axvspan(mean_co60_1-err_co60_1, mean_co60_1+err_co60_1, alpha=0.2, color='k', label='Uncertainty')

ax.set_xlabel('Channel Number (proportional to energy)')
ax.set_ylabel('Number of Counts')
ax.set_title('Energy Fit Co60 First Peak')

ax.set_xlim(320, 345)
ax.minorticks_on()
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)

ax.legend()

plt.show()

# %% [markdown]
# ## Cobalt Peak 2

# %%
limits = [365, 390]

# %%
mask = (df.index>limits[0]) & (df.index<limits[1])
p0  = (np.mean(df.index[mask]), np.std(df.index[mask]), np.max(df['co60'][mask]))

popt, pcov = curve_fit(norm, df.index[mask], df['co60'][mask], p0=p0)
perr = np.sqrt(np.diag(pcov))

# %%
mean_co60_2 = popt[0]
err_co60_2 = perr[0]

# %%
fig, ax = plt.subplots(figsize=(6,4))

df['co60'].plot(ax=ax)
ax.plot(norm(df.index, mean_co60_2, popt[1], popt[2]))

ax.axvline(mean_co60_2, color='k', linestyle='--', label='Mean Value')
ax.axvspan(mean_co60_2-err_co60_2, mean_co60_2+err_co60_2, alpha=0.2, color='k', label='Uncertainty')

ax.set_xlabel('Channel Number (proportional to energy)')
ax.set_ylabel('Number of Counts')
ax.set_title('Energy Fit Co60 Second Peak')

ax.set_xlim(limits[0], limits[1])
ax.minorticks_on()
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)

ax.legend()

plt.show()

# %% [markdown]
# ## Sodium Peak

# %%
limits = [138, 160]

# %%
mask = (df.index>limits[0]) & (df.index<limits[1])
p0  = (np.mean(df.index[mask]), np.std(df.index[mask]), np.max(df['na22'][mask]))

popt, pcov = curve_fit(norm, df.index[mask], df['na22'][mask], p0=p0)
perr = np.sqrt(np.diag(pcov))

# %%
mean_na22 = popt[0]
err_na22 = perr[0]

# %%
fig, ax = plt.subplots(figsize=(6,4))

df['na22'].plot(ax=ax)
ax.plot(norm(df.index, mean_na22, popt[1], popt[2]))

ax.axvline(mean_na22, color='k', linestyle='--', label='Mean Value')
ax.axvspan(mean_na22-err_na22, mean_na22+err_na22, alpha=0.2, color='k', label='Uncertainty')

ax.set_xlabel('Channel Number (proportional to energy)')
ax.set_ylabel('Number of Counts')
ax.set_title('Energy Fit Na22')

ax.set_xlim(limits[0], limits[1])
ax.minorticks_on()
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)

ax.legend()

plt.show()

# %% [markdown]
# ## Cesium Peak

# %%
limits = [180, 200]

# %%
mask = (df.index>limits[0]) & (df.index<limits[1])
p0  = (np.mean(df.index[mask]), np.std(df.index[mask]), np.max(df['cs137'][mask]))

popt, pcov = curve_fit(norm, df.index[mask], df['cs137'][mask], p0=p0)
perr = np.sqrt(np.diag(pcov))

# %%
mean_cs137 = popt[0]
err_cs137 = perr[0]

# %%
fig, ax = plt.subplots(figsize=(6,4))

df['cs137'].plot(ax=ax)
ax.plot(norm(df.index, mean_cs137, popt[1], popt[2]))

ax.axvline(mean_cs137, color='k', linestyle='--', label='Mean Value')
ax.axvspan(mean_cs137-err_cs137, mean_cs137+err_cs137, alpha=0.2, color='k', label='Uncertainty')

ax.set_xlabel('Channel Number (proportional to energy)')
ax.set_ylabel('Number of Counts')
ax.set_title('Energy Fit Cs137')

ax.set_xlim(limits[0], limits[1])
ax.minorticks_on()
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)

ax.legend()

plt.show()

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Define the Energy Peaks

# %%
co_peak_1 = 1173.2
co_peak_2 = 1332.5
cs_peak = 661.657
na_peak = 511

energies = np.array([na_peak, cs_peak, co_peak_1, co_peak_2])

# %% [markdown]
# ## Define the Channel Peaks

# %%
channel_mean_na22 = ufloat(mean_na22, err_na22)
channel_mean_cs137 = ufloat(mean_cs137, err_cs137)
channel_mean_co60_1 = ufloat(mean_co60_1, err_co60_1)
channel_mean_co60_2 = ufloat(mean_co60_2, err_co60_2)

channels_unc = np.array([channel_mean_na22, channel_mean_cs137, channel_mean_co60_1, channel_mean_co60_2])
channels = np.array([x.nominal_value for x  in channels]) #no uncertainties when plotting

# %% [markdown]
# ## Inital Plot

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.scatter(channels,energies)

ax.set_xlabel('Channel Number')
ax.set_ylabel('Energy (keV)')
ax.set_title('Energy as a Function of Channel Number')

ax.minorticks_on()
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)

ax.set_xlim(0,400)
ax.set_ylim(0,1500)


plt.show()

# %% [markdown]
# We can use least squares fit on any **three** of these points and then predict what the value of the fourth point should be.

# %%
def get_energy_per_channel(channel_mean_1, channel_mean_2, energy_1, energy_2):
    return (energy_2-energy_1)/(channel_mean_2-channel_mean_1)

# %%
scale = get_energy_per_channel(channel_mean_cs137, channel_mean_co60_1,
                      cs_peak, co_peak_1)
scale
# Out:
# 3.601147161091843+/-0.0022860846905139254

# %% [markdown]
# Need to subtract 7 because channel 7 has energy 0.

# %%
(channel_mean_co60_1-7)*scale
# Out:
# 1166.716247278383+/-1.587040185664697
