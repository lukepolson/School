# %% [markdown]
# # Import Packages and Data

# %% [markdown]
# Import packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Import data

# %%
ac = np.loadtxt('A5_data/ac.txt')
s = np.loadtxt('A5_data/s.txt')
time = np.loadtxt('A5_data/time.txt')
fs = 1/(time[1]-time[0])

df = pd.DataFrame({'time':time, 's':s, 'ac':ac})

# %% [markdown]
# # Important Note

# %% [markdown]
# Through this assignment the units of our periodograms are $V^2/\text{Hz}$ where $V$ is the unit of $s^{-1}$, which also happens to be Hz (aka $V=\text{Hz}$). We choose to write $V^2/\text{Hz}$ because $\text{Hz}^2/\text{Hz}$ is not as pleasant to the eye.
#
# Note that the power at zero frequencies is not plotted (similar to what you do in your example plots).

# %% [markdown]
# # Question 1

# %% [markdown]
# Obtain the times and the data.

# %%
times = df['time'][df['time']<=20]
ss= df['s'][df['time']<=20]
acs= df['ac'][df['time']<=20]

# %% [markdown]
# Plot

# %%
plt.figure(figsize=(10,5))
plt.plot(times, ss, label='$dU/dx$', lw=0.5)
plt.plot(times, acs, label='$dU_a/dx$', lw=0.5)
plt.legend(fontsize=16)
plt.xlabel('Time [s]')
plt.ylabel('Shear [Hz]')
plt.title('Shear as a function of time', fontsize=20)
plt.grid()

plt.show()

# %% [markdown]
# Lets qualitatively compare the data:
#
# * There is more variance seen in $dU/dx$ than in $dU_a/dx$. This makes sense: $dU_a/dx$ measures vibrations of the instrument that contaminate $dU/dx$. While these vibrations are contained in $dU/dx$ as well, the shear probe also picks up on additional processes.
#
# * There are a few large spikes in $dU/dx$ (seen at approximately 10s, 13s, and 15.5s) not seen in $dU_a/dx$. This suggests that these spikes are due to the something from the ocean (or error in the shear probe) and not due to vibrations of the instrument.
#
# * $dU_a/dx$: There is a distinct high frequency seen in this time series. There are also lower frequencies present.
#
# * $dU/dx$: Most of the variance here appears to come from some sort of high-ish frequency observed throughout the entire time series.
#
# * Note that $dU_a/dx$ does not have a mean of 0 shear while $dU/dx$ does have a mean of (approximately) zero shear.

# %% [markdown]
# # Question 2

# %% [markdown]
# Note: Throughout this assignment, "nperseg" is the equivalent of "nfft" which you mention in your assignment.
# this is because nfft defaults to nperseg. See https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.signal.welch.html for more information.

# %%
from scipy.signal import welch

# %% [markdown]
# Below we use...
#
# * hanning windows as our taper with npserseg/2 overlap.
# *  zero padding since the time series is not always a multiple of nperseg. Note that scipy uses zero padding when nperseg is not a multiple of the time series.
# * detrending which removes any linear trend of the segments of length nperseg/2. This can decrease the variance; this is discussed shortly.

# %%
# Compute for dat.s
ff_s1, spec_s1 = welch(s, fs=fs, nperseg=64, window='hann') 
ff_s2, spec_s2 = welch(s, fs=fs, nperseg=256, window='hann') 
ff_s3, spec_s3 = welch(s, fs=fs, nperseg=2560, window='hann') 
ff_s4, spec_s4 = welch(s, fs=fs, nperseg=24000, window='hann') 

# Compute for dat.ac
ff_ac1, spec_ac1 = welch(ac, fs=fs, nperseg=64, window='hann') 
ff_ac2, spec_ac2 = welch(ac, fs=fs, nperseg=256, window='hann') 
ff_ac3, spec_ac3 = welch(ac, fs=fs, nperseg=2560, window='hann') 
ff_ac4, spec_ac4 = welch(ac, fs=fs, nperseg=24000, window='hann')

# %% [markdown]
# ## $dU/dx$  Spectrum

# %% [markdown]
# Plot spectrum

# %%
plt.figure(figsize=(15,5))
plt.loglog(ff_s4, spec_s4, alpha=0.7, label='nfft=24000')
plt.loglog(ff_s3[1:], spec_s3[1:], alpha=0.7, label='nfft=2560')
plt.loglog(ff_s2[1:], spec_s2[1:], lw=3, label='nfft=256')
plt.loglog(ff_s1[1:], spec_s1[1:], lw=3, label='nfft=64')
plt.ylim(bottom=10**(-8))
plt.grid()
plt.legend(fontsize=12)
plt.ylabel(r'$S_{xx}(f)  [V^2/Hz]$', fontsize=16)
plt.xlabel(r'$f [Hz]$', fontsize=16)
plt.title('Spectral Estimators of $dU/dx$ for Different nfft Lengths (Hanning Window)', fontsize=20)
plt.show()

# %% [markdown]
# Comparison:
# * As nfft decreases, we lose energy at lower frequencies. This is due to the detrending feature of the welch method used which de-means each segment (nfft points) of the series. This effectively removes the low frequencies.
# * As nfft decreases we lose the resolution at each spike. This is due to the fact that with smaller segments, we can not estimate as dense a grid of frequencies (since each segment is shorter), so the peaks get convoluted.

# %% [markdown]
# **Side Note**: Below is a comparison of nfft=64 with a linear detrend vs. no detrend.

# %%
ff_s2_nd, spec_s2_nd = welch(s, fs=fs, nperseg=256, window='hanning', detrend=False)

# %%
plt.figure(figsize=(8,3))
plt.loglog(ff_s2[1:], spec_s2[1:], lw=2, label='Linear Detrend')
plt.loglog(ff_s2_nd[1:], spec_s2_nd[1:], lw=2, label='No Detrend')
plt.ylim(bottom=10**(-8))
plt.grid()
plt.legend(fontsize=12)
plt.ylabel(r'$S_{xx}(f)  [V^2/Hz]$', fontsize=12)
plt.xlabel(r'$f [Hz]$', fontsize=12)
plt.title('Spectral Estimators of $dU/dx$; nfft=256; Linear Detrend vs. No Detrend (Hanning Window)', fontsize=10)
plt.show()

# %% [markdown]
# Notice a significant increase in power at lower frequencies with no detrend used.

# %% [markdown]
# ## $dU_a/dx$  Spectrum

# %%
plt.figure(figsize=(15,5))
plt.loglog(ff_ac4[1:], spec_ac4[1:], alpha=0.7, label='nfft=24000')
plt.loglog(ff_ac3[1:], spec_ac3[1:], alpha=0.7, label='nfft=2560')
plt.loglog(ff_ac2[1:], spec_ac2[1:], lw=3, label='nfft=256')
plt.loglog(ff_ac1[1:], spec_ac1[1:], lw=3, label='nfft=64')
plt.ylim(bottom=10**(-9))
plt.grid()
plt.legend(fontsize=12)
plt.ylabel(r'$S_{xx}(f)  [V^2/Hz]$', fontsize=16)
plt.xlabel(r'$f [Hz]$', fontsize=16)
plt.title('Spectral Estimators of $dU_a/dx$ for Different nfft Lengths (Hanning Window)', fontsize=20)
plt.show()

# %% [markdown]
# Lets check to make sure this definition of the spectrum is indeed the definition you gave us: i.e. the integral of the spectrum should yield the variance of $s$ (assuming $s$ has zero mean- which it basically does).

# %%
np.var(s)
# Out:
# 0.0023982981542625013

# %% [markdown]
# Lets check the spectra:

# %%
print('Variance from nperseg=64 is {}'.format(sum(spec_s1)*(ff_s1[1]-ff_s1[0])))
print('Variance from nperseg=256 is {}'.format(sum(spec_s2)*(ff_s2[1]-ff_s2[0])))
print('Variance from nperseg=2560 is {}'.format(sum(spec_s3)*(ff_s3[1]-ff_s3[0])))
print('Variance from nperseg=24000 is {}'.format(sum(spec_s4)*(ff_s4[1]-ff_s4[0])))
# Out:
# Variance from nperseg=64 is 0.002285464117037285
# Variance from nperseg=256 is 0.0023243783560650544
# Variance from nperseg=2560 is 0.0022487410868057126
# Variance from nperseg=24000 is 0.0007914163656323695

# %% [markdown]
# Note that the npserseg=24000 spectrum underestimates the variance: this is due to zero-padding used in the scipy procedure. We can do the same test with the ac data set.

# %%
np.var(ac-np.mean(ac))
# Out:
# 0.0010867773231812284

# %%
print('Variance from nperseg=64 is {}'.format(sum(spec_ac1)*(ff_ac1[1]-ff_ac1[0])))
print('Variance from nperseg=256 is {}'.format(sum(spec_ac2)*(ff_ac2[1]-ff_ac2[0])))
print('Variance from nperseg=2560 is {}'.format(sum(spec_ac3)*(ff_ac3[1]-ff_ac3[0])))
print('Variance from nperseg=24000 is {}'.format(sum(spec_ac4)*(ff_ac4[1]-ff_ac4[0])))
# Out:
# Variance from nperseg=64 is 5.7452742223186806e-05
# Variance from nperseg=256 is 0.0001205558631867668
# Variance from nperseg=2560 is 0.0007661419842409422
# Variance from nperseg=24000 is 0.0006423113217734421

# %% [markdown]
# Note that we vastly underestimate the variance for nfft=64. This is due to the fact that the spectrum of $dU_a/dx$ has significant energy at low frequencies; when we use a small window with a hanning taper (and the **detrend**=True argument in the welch method) we remove any height offset of the segments used. This in turn reduces the variance of the time series. The estimate for the variance gets better as we approach npserseg =  256 and 2560, but then it drops again at 24000. This, again, is due to the zero padding procedure used by scipy, which effectively decreases the variance of the time series.

# %% [markdown]
# ## Comparison of the Two Signals

# %% [markdown]
# * Both signals have spikes in power at ~20Hz and ~50Hz. These are likely due to vibrations of the instrument.
# * The $dU_a/dx$ signal has a few spikes at (approximately) evenly spaced frequencies (see **dotted red lines** in plot below). These may be indicative of some sort of harmonics occuring in the vibration instrument. These peaks are not seen in the shear probe because other signals are being measured which have much more energy at these frequencies.
# * Other than the 20Hz and 50Hz spikes, and the harmonics mentioned above, the shear probe has between 1-2 orders of magnitude more energy measured at each frequency. This makes sense, the shear probe is picking up signals from the ocean (*in addition* to vibrations from the accelerometer).
#
# The plot below is shown in semilog to emphasize the fact that the harmonic frequencies are evenly spaced apart.

# %%
peaks = [9.2, 26.3, 43.2, 60.3]

plt.figure(figsize=(15,5))
[plt.axvline(peak, color='r', ls='--', alpha=0.5) for peak in peaks]
plt.semilogy(ff_ac3, spec_ac3, alpha=0.7, label='Accelerometer')
plt.semilogy(ff_s3, spec_s3, alpha=0.7, label='Shear Probe')
plt.ylim(bottom=10**(-9))
plt.grid()
plt.legend(fontsize=12)
plt.ylabel(r'$S_{xx}(f)  [V^2/Hz]$', fontsize=16)
plt.xlabel(r'$f [Hz]$', fontsize=16)
plt.title('Spectral Estimators of $dU_a/dx$ and $dU/dx$ (Hanning Window, nfft=2560)', fontsize=20)
plt.show()

# %% [markdown]
# # Question 3

# %% [markdown]
# Here we show the effects of aliasing. Theoretically we know that
#
# $$\hat{S_{x_t}}(f) = \sum_{k=-\infty}^\infty S_{x(t)}(f+k/\Delta t)$$
#
# where $x_t$ is our discretely sampled time series, $x(t)$ is our true continuous process, $\hat{S_{x_t}}$ is the spectral estimator (obtained using $x_t$) of true spectrum  $S_{x(t)}$  and $\Delta t = 1/f$ where $f$ is our sampling frequency. For a normal spectrum, we don't take the sum from $-\infty$ to $\infty$, we might only choose a few intervals of $k$.
#
# Note that we are dealing with spectral estimators, not the true spectra. Thus the forumla above holds to some approximation.   We show the effects of aliasing in two ways
#
# * We sub sample the time series and plot the spectrum  <mark>(**what you asked of us**)</mark>
# * We manually "flip in" the spectrum using the formula above. In other words, we take the spectrum for the normally sampled time series, split it up into many intervals, and add the intervals together (flipping some as required, as we are considering a 1-sided PSD). <mark>(**bonus**)</mark>
#
# The functions defined below are used for my second bullet point above.

# %%
def split_padded(a,n):
    padding = len(a)//n - len(a)%n
    return np.split(np.concatenate((a,np.zeros(padding))),(n+1))

def fold_in(prdg, scale):
    f = split_padded(prdg, scale)
    N = len(f[0])
    
    ff = np.linspace(0, 1/2, N) *fs/scale
    new_prdg = f[0]
    for (i, arr) in enumerate(f[1:]):
        if i%2 == 1:
            new_prdg += arr
        else:
            new_prdg += np.flip(arr)
    
    
    return ff, new_prdg

# %% [markdown]
# Compute the regular spectrum, the spectrum of the sub sampled time series, and the "flipped-in" spectrum.

# %%
s_subsamp = s[::10]

ff_s, spec_s = welch(s, fs=fs, nperseg=2560, noverlap=0, window='hann') 
ff_ssub, spec_ssub = welch(s_subsamp, fs=fs/10, nperseg=256, window='hann') 
ff_ssub_theo, spec_ssub_theo = fold_in(spec_s, 10)

# %% [markdown]
# Plot full spectrum.

# %%
plt.figure(figsize=(15,5))

plt.loglog(ff_s[1:], spec_s[1:], label='Normal')
plt.loglog(ff_ssub[1:], spec_ssub[1:],  label='Subsampled')
plt.loglog(ff_ssub_theo[1:], spec_ssub_theo[1:], label='Theoretical Subsampled', ls='--', lw=1, c='green')

plt.ylim(bottom=10**(-7))
plt.grid()
plt.legend(fontsize=12)
plt.ylabel(r'$S_{xx}(f)  [V^2/Hz]$', fontsize=16)
plt.xlabel(r'$f [Hz]$', fontsize=16)
plt.title('Effects of Aliasing when Subsampling $dU/dx$ (Hanning Window Used)', fontsize=20)
plt.show()

# %% [markdown]
# Note that the theoretical subsampled spectrum and subsampled spectrum don't match perfectly. This is because we are looking at one of the 10 possible subsampled version of the spectrum (for example: we could've started at i=0, i=1, i=2, ... i=8 of the time series when subsampling every 10 points).

# %% [markdown]
# Now we compute the variance (as the integral of the spectrum). Note that it should *not* change because we have folded back power into the lower frequency region.

# %%
print('Variance from Normal is {}'.format(sum(spec_s)*(ff_s[1]-ff_s[0])))
print('Variance from Sub-sampled is {}'.format(sum(spec_ssub)*(ff_ssub[1]-ff_ssub[0])))
print('Variance from Theoretical Sub-sampled is {}'.format(sum(spec_ssub_theo)*(ff_ssub_theo[1]-ff_ssub_theo[0])))
# Out:
# Variance from Normal is 0.002341632036528753
# Variance from Sub-sampled is 0.002247658392573995
# Variance from Theoretical Sub-sampled is 0.0023600700840604783

# %% [markdown]
# These should be equal to the variance of $s$ (approximately).

# %%
np.var(s)
# Out:
# 0.0023982981542625013

# %% [markdown]
# and they are indeed!

# %% [markdown]
# # Question 4

# %% [markdown]
# Use a running mean for smoothing

# %%
v = 1/(10) * (np.zeros(10)+1)
s_smooth = np.convolve(s, v, mode='same') # keep time series same length
s_smooth_sub = s_smooth[::10]

ffs_smooth_sub, specs_smooth_sub = welch(s_smooth_sub, fs=fs/10, nperseg=256, noverlap=0, window='hann')

# %% [markdown]
# Plot the signal

# %%
plt.figure(figsize=(10,5))
plt.plot(time[0:100], s_smooth[0:100], label='Smoothed Signal')
plt.plot(time[0:100], s[0:100], label='Signal')
plt.legend(fontsize=16)
plt.xlabel('Time [s]')
plt.ylabel('Shear [Hz]')
plt.title('Smoothed Vs. Regular Time Series (Subsample)', fontsize=20)
plt.grid()

plt.show()

# %% [markdown]
# Compare the spectra. Plot full spectrum.

# %%
plt.figure(figsize=(15,5))
plt.loglog(ff_s[1:], spec_s[1:], label='Regular')
plt.loglog(ffs_smooth_sub[1:], specs_smooth_sub[1:], label='Smoothed')
plt.ylim(bottom=10**(-7))
plt.grid()
plt.legend(fontsize=12)
plt.ylabel(r'$S_{xx}(f)  [V^2/Hz]$', fontsize=16)
plt.xlabel(r'$f [Hz]$', fontsize=16)
plt.title('Spectral Estimators of $dU/dx$ (Smoothed vs. Normal)', fontsize=20)
plt.show()

# %% [markdown]
# Unlike question 3, we no longer have more power in lower frequencies in the subsampled spectrum In other words, no "folding back" of the spectrum has occurred, which
#
# $$\hat{S_{x_t}}(f) = \sum_{k=-\infty}^\infty S_{x(t)}(f+k/\Delta t)$$
#
# predicts. Why is this the case? This is due to the fact that the discrete time series $x_t$ has been filtered such that the power in all frequencies above the new nyquist frequency $1/(2 \Delta t_{new}) = 1/(20 \Delta t) = 7.8125 \text{Hz}$ are removed. This is charateristic of the fact that the integral is a low pass filter (the running mean is an "effective" discrete integral). Thus the smoothed time series loses energy at these higher frequencies, and we expect the periodograms to be identical in the low frequency region.
#
# Below we compare variances

# %%
print('Variance of s: {}'.format(np.var(s)))
print('Variance from Normal is {}'.format(sum(spec_s)*(ff_s[1]-ff_s[0])))
print('Variance from Smoothed, Sub-sampled is {}'.format(sum(specs_smooth_sub)*(ffs_smooth_sub[1]- ffs_smooth_sub[0])))
# Out:
# Variance of s: 0.0023982981542625013
# Variance from Normal is 0.002341632036528753
# Variance from Smoothed, Sub-sampled is 0.00034407847295414963

# %% [markdown]
# As expected, the variance estimate of the time series has decreased due to filtering.

# %% [markdown]
# # Question 5

# %% [markdown]
# Obtain the active and quiet phases of $s$.

# %%
times_act = time[(time>=200)&(time<=250)]
s_act = s[(time>=200)&(time<=250)]

times_qui = time[(time>=50)&(time<=100)]
s_qui = s[(time>=50)&(time<=100)]

# %% [markdown]
# Plot the differences

# %%
fig, axes = plt.subplots(1,2,figsize=(16,3))

ax = axes[0]
ax.plot(times_qui, s_qui, lw=0.1)
ax.set_xlabel('Time [s]')
ax.set_ylabel('Shear Rate [Hz]')
ax.set_title('Quiet Phase of $dU/dx$', fontsize=14)
ax.grid()

ax = axes[1]
ax.plot(times_act, s_act, lw=0.1)
ax.set_xlabel('Time [s]')
ax.set_ylabel('Shear Rate [Hz]')
ax.set_title('Active Phase of $dU/dx$', fontsize=14)
ax.grid()

# %% [markdown]
# There are a few differences between these two plots:
#  * The active phase appears to have more energy at some low frequency (this is apparent in the lobes of the active phase plot). While there are lobes in the quiet phase plot, they are not as prevalent (relative to the other frequencies).
#  * The upper and lower bounds on the quiet phase plot (-0.05 Hz and 0.05 Hz) are smaller than the upper and lower bounds on the active phase plot (-0.3 Hz and 0.3 Hz). This suggests that there is more variance in the active phase plot, and accordingly that a difference process is taking place between the two time frames.

# %% [markdown]
# Obtain the spectra.

# %%
ff_s_act, spec_s_act = welch(s_act, fs=fs, nperseg=256, noverlap=0, window='hann') 
ff_s_qui, spec_s_qui = welch(s_qui, fs=fs, nperseg=256, noverlap=0, window='hann')

# %% [markdown]
# Plot.

# %%
plt.figure(figsize=(15,5))
plt.loglog(ff_s_qui[1:], spec_s_qui[1:], label='Quiet Phase')
plt.loglog(ff_s_act[1:], spec_s_act[1:], label='Active Phase')
plt.ylim(bottom=10**(-7))
plt.grid()
plt.legend(fontsize=12)
plt.ylabel(r'$S_{xx}(f)  [V^2/Hz]$', fontsize=16)
plt.xlabel(r'$f [Hz]$', fontsize=16)
plt.title('Spectral Estimators of Active and Passive Phase of $s$', fontsize=20)
plt.show()

# %% [markdown]
# The differences are
#
# * **Low Frequency Region**: The active phase appears to have more energy in all lower frequencies up to around 45Hz. This observation supports the claim we made above when comparing the time series: there are low frequency lobes present in the active phase that are not as apparent in the quiet phase. The power at these low frequencies is likely due to the turbulent motion of the ocean being "active" during the active phase, and "quiet" during the quiet phase.
# * **Mid Frequency Spike**: The active phase has about 10 times more energy in the frequency spike of 50Hz. This *may* suggest that something in the physical process occurs at around 50Hz. Note that this spike is still visibile in the quiet phase, suggesting that it always takes place. Note that we discussed this in your office: it is likely vibrations caused by the boat. The larger spike during the active phase is just a coincidence: the shear probe just so happened to be moving faster during the active phase. It is unlikley the shear probe is picking up some ocean turbulence at this frequency.
# * **High Frequency Range**: Above 55Hz, the two spectra are approximately equal. What ever is occuing in the "active" phase does not occur at high frequencies. In other words, these frequencies are likely due to the vibrations of the instrument.

# %% [markdown]
# # Question 6

# %%
from scipy.signal import coherence

# %% [markdown]
# Obtain active and quiet data.

# %%
times_act = time[(time>=200)&(time<=250)]
s_act = s[(time>=200)&(time<=250)]
ac_act = ac[(time>=200)&(time<=250)]

times_qui = time[(time>=50)&(time<=100)]
s_qui = s[(time>=50)&(time<=100)]
ac_qui = ac[(time>=50)&(time<=100)]

# %% [markdown]
# Obtain coherence estimates.

# %%
ff_act, cohere_act = coherence(s_act, ac_act, fs=fs, nperseg=256, window='hann') 
ff_qui, cohere_qui = coherence(s_qui, ac_qui, fs=fs, nperseg=256, window='hann')

# %% [markdown]
# Plot.

# %%
plt.figure(figsize=(15,5))
plt.semilogx(ff_qui[1:], cohere_qui[1:], label='Quiet Phase')
plt.semilogx(ff_act[1:], cohere_act[1:], label='Active Phase')
plt.grid()
plt.legend(fontsize=12)
plt.ylabel(r'Coherence', fontsize=16)
plt.xlabel(r'$f [Hz]$', fontsize=16)
plt.title('Coherence Between Active and Passive Phase of $s$ and $ac$', fontsize=20)
plt.show()

# %% [markdown]
# Which is more coherent: The active of the passive region?:
#
# * **Quiet vs. Active Phase**: Up to approximately 35Hz, $s$ is more coherent with $ac$ during the quiet phase. This is likely caused by more ocean turbulence during the active phase, which is picked up by $s$, but not $ac$. In both the quiet and the active phase, $s$ and $ac$ are nearly perfectly coherent at 55Hz. This is likely caused by vibrations of the instrument present during both the quiet and active phases.
#
# * **In conclusion:** Absent of the 55Hz vibrations, the quiet phase is more coherent than the active phase. As discussed, this is due to the fact that during the active phase, the sheer probe is measuring ocean turbulence not measured by the accelerometer, so the low frequency component of each time series is unrelated to the other.
