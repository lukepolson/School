# %%
% matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from scipy import integrate
from mpl_toolkits.mplot3d import Axes3D 
from matplotlib import cm
from scipy.stats import norm

j = complex(0,1)

# %%
scl = 1

def func(x, y, scl):
    X = x/scl
    Y = y/scl
    
    R = 20*np.sqrt(X**2+Y**2)
    return np.heaviside(R, 1) - np.heaviside(R-11, -1)

def func2(x, y):
    return norm.pdf(x, 0, 1)*norm.pdf(y, 0, 1)


x0 = -10*scl
dx = 0.05 * scl
x=np.arange(x0,-x0,dx)
y0 = -10*scl
dy = 0.05*scl
y=np.arange(y0,-y0,dy)

# %%
X, Y = np.meshgrid(x,y)
nonfour = func2(X, Y)

# %%
fig = plt.figure()
plt.imshow(nonfour)
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
g=np.fft.fft2(nonfour)
G = 1/(np.sqrt(np.pi))*np.fft.fftshift( g )

plt.imshow(np.abs(G))
#plt.xlim([512-1024*scale/2,512+1024*scale/2])
#plt.ylim([512-1024*scale/2,512+1024*scale/2])
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
